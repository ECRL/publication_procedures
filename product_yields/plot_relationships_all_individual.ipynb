# %%
from csv import DictReader

with open('_data/fluidized_bed.csv', 'r') as csv_file:
    reader = DictReader(csv_file)
    rows_fb = [r for r in reader]
csv_file.close()

with open('_data/batch_reactor.csv', 'r') as csv_file:
    reader = DictReader(csv_file)
    rows_br = [r for r in reader]
csv_file.close()

with open('_data/tubular_reactor.csv', 'r') as csv_file:
    reader = DictReader(csv_file)
    rows_tr = [r for r in reader]
csv_file.close()

rows = rows_fb[:]
rows.extend(rows_br)
rows.extend(rows_tr)

# %%
from typing import List, Tuple

def get_yields(rows: List[dict], inp: str, inp_limit: int = None) -> Tuple[List[float]]:
    """ Only retrieves samples with all data (input var, % yields) available """

    input, oil, char, gas = [], [], [], []
    for row in rows:
        try:
            _i = float(row[inp])
            if inp_limit:
                if _i > inp_limit: continue
            _o = float(row['Oil'])
            _c = float(row['Char'])
            _g = float(row['Gas'])
            input.append(_i)
            oil.append(_o)
            char.append(_c)
            gas.append(_g)
        except:
            continue
    return (input, oil, char, gas)

# %%
# Reaction Time (s) vs. Oil Yield
from matplotlib import pyplot as plt

t_reaction, oil, _, _ = get_yields(rows, 'Reaction Time (s)', inp_limit=750.0)

plt.clf()
plt.rcParams['font.family'] = 'Times New Roman'
plt.xlabel('Reaction Time (s)')
plt.ylabel('% Yield')
plt.scatter(t_reaction, oil, color=(0, 114/235, 178/235), label='Oil', alpha=0.5)
plt.savefig('_plots/inp_tar/all_reactors/reaction_time_oil.png')
plt.show()

# %%
# Reaction Time (s) vs. Char Yield

t_reaction, _, char, _ = get_yields(rows, 'Reaction Time (s)', inp_limit=750.0)

plt.clf()
plt.rcParams['font.family'] = 'Times New Roman'
plt.xlabel('Reaction Time (s)')
plt.ylabel('% Yield')
plt.scatter(t_reaction, char, color=(0, 158/235, 115/235), label='Char', alpha=0.5)
plt.savefig('_plots/inp_tar/all_reactors/reaction_time_char.png')
plt.show()

# %%
# Reaction Time (s) vs. Gas Yield

t_reaction, _, _, gas = get_yields(rows, 'Reaction Time (s)', inp_limit=750.0)

plt.clf()
plt.rcParams['font.family'] = 'Times New Roman'
plt.xlabel('Reaction Time (s)')
plt.ylabel('% Yield')
plt.scatter(t_reaction, gas, color=(213/235, 94/235, 0), label='Gas', alpha=0.5)
plt.savefig('_plots/inp_tar/all_reactors/reaction_time_gas.png')
plt.show()

# %%
# Temperature (C) vs. Oil Yield

temp, oil, _, _ = get_yields(rows, 'Temperature (C)')

plt.clf()
plt.rcParams['font.family'] = 'Times New Roman'
plt.xlabel('Temperature (C)')
plt.ylabel('% Yield')
plt.scatter(temp, oil, color=(0, 114/235, 178/235), label='Oil', alpha=0.5)
plt.savefig('_plots/inp_tar/all_reactors/temperature_oil.png')
plt.show()

# %%
# Temperature (C) vs. Char Yield

temp, _, char, _ = get_yields(rows, 'Temperature (C)')

plt.clf()
plt.rcParams['font.family'] = 'Times New Roman'
plt.xlabel('Temperature (C)')
plt.ylabel('% Yield')
plt.scatter(temp, char, color=(0, 158/235, 115/235), label='Char', alpha=0.5)
plt.savefig('_plots/inp_tar/all_reactors/temperature_char.png')
plt.show()

# %%
# Temperature (C) vs. Gas Yield

temp, _, _, gas = get_yields(rows, 'Temperature (C)')

plt.clf()
plt.rcParams['font.family'] = 'Times New Roman'
plt.xlabel('Temperature (C)')
plt.ylabel('% Yield')
plt.scatter(temp, gas, color=(213/235, 94/235, 0), label='Gas', alpha=0.5)
plt.savefig('_plots/inp_tar/all_reactors/temperature_gas.png')
plt.show()

# %%
# Particle size (mm) vs. Oil Yield

part_size, oil, _, _ = get_yields(rows, 'Particle size (mm)')

plt.clf()
plt.rcParams['font.family'] = 'Times New Roman'
plt.xlabel('Particle size (mm)')
plt.ylabel('% Yield')
plt.scatter(part_size, oil, color=(0, 114/235, 178/235), label='Oil', alpha=0.5)
plt.savefig('_plots/inp_tar/all_reactors/particle_size_oil.png')
plt.show()

# %%
# Particle size (mm)

part_size, _, char, _ = get_yields(rows, 'Particle size (mm)')

plt.clf()
plt.rcParams['font.family'] = 'Times New Roman'
plt.xlabel('Particle size (mm)')
plt.ylabel('% Yield')
plt.scatter(part_size, char, color=(0, 158/235, 115/235), label='Char', alpha=0.5)
plt.savefig('_plots/inp_tar/all_reactors/particle_size_char.png')
plt.show()

# %%
# Particle size (mm) vs. Gas Yield

part_size, _, _, gas = get_yields(rows, 'Particle size (mm)')

plt.clf()
plt.rcParams['font.family'] = 'Times New Roman'
plt.xlabel('Particle size (mm)')
plt.ylabel('% Yield')
plt.scatter(part_size, gas, color=(213/235, 94/235, 0), label='Gas', alpha=0.5)
plt.savefig('_plots/inp_tar/all_reactors/particle_size_gas.png')
plt.show()

# %%
# Moisture vs. Oil Yield

moisture, oil, _, _ = get_yields(rows, 'Moisture')

plt.clf()
plt.rcParams['font.family'] = 'Times New Roman'
plt.xlabel('% Moisture Content')
plt.ylabel('% Yield')
plt.scatter(moisture, oil, color=(0, 114/235, 178/235), label='Oil', alpha=0.5)
plt.savefig('_plots/inp_tar/all_reactors/moisture_oil.png')
plt.show()

# %%
# Moisture vs. Char Yield

moisture, _, char, _ = get_yields(rows, 'Moisture')

plt.clf()
plt.rcParams['font.family'] = 'Times New Roman'
plt.xlabel('% Moisture Content')
plt.ylabel('% Yield')
plt.scatter(moisture, char, color=(0, 158/235, 115/235), label='Char', alpha=0.5)
plt.savefig('_plots/inp_tar/all_reactors/moisture_char.png')
plt.show()

# %%
# Moisture vs. Gas Yield

moisture, _, _, gas = get_yields(rows, 'Moisture')

plt.clf()
plt.rcParams['font.family'] = 'Times New Roman'
plt.xlabel('% Moisture Content')
plt.ylabel('% Yield')
plt.scatter(moisture, gas, color=(213/235, 94/235, 0), label='Gas', alpha=0.5)
plt.savefig('_plots/inp_tar/all_reactors/moisture_gas.png')
plt.show()

# %%
# Ash vs. Oil Yield

ash, oil, _, _ = get_yields(rows, 'Ash')

plt.clf()
plt.rcParams['font.family'] = 'Times New Roman'
plt.xlabel('% Ash Content')
plt.ylabel('% Yield')
plt.scatter(ash, oil, color=(0, 114/235, 178/235), label='Oil', alpha=0.5)
plt.savefig('_plots/inp_tar/all_reactors/ash_oil.png')
plt.show()

# %%
# Ash vs. Char Yield

ash, _, char, _ = get_yields(rows, 'Ash')

plt.clf()
plt.rcParams['font.family'] = 'Times New Roman'
plt.xlabel('% Ash Content')
plt.ylabel('% Yield')
plt.scatter(ash, char, color=(0, 158/235, 115/235), label='Char', alpha=0.5)
plt.savefig('_plots/inp_tar/all_reactors/ash_char.png')
plt.show()

# %%
# Ash vs. Gas Yield

ash, _, _, gas = get_yields(rows, 'Ash')

plt.clf()
plt.rcParams['font.family'] = 'Times New Roman'
plt.xlabel('% Ash Content')
plt.ylabel('% Yield')
plt.scatter(ash, gas, color=(213/235, 94/235, 0), label='Gas', alpha=0.5)
plt.savefig('_plots/inp_tar/all_reactors/ash_gas.png')
plt.show()

# %%
# Carbon vs. Oil Yield

carbon, oil, _, _ = get_yields(rows, 'C')

plt.clf()
plt.rcParams['font.family'] = 'Times New Roman'
plt.xlabel('% Carbon Content')
plt.ylabel('% Yield')
plt.scatter(carbon, oil, color=(0, 114/235, 178/235), label='Oil', alpha=0.5)
plt.savefig('_plots/inp_tar/all_reactors/carbon_oil.png')
plt.show()

# %%
# Carbon vs. Char Yield

carbon, _, char, _ = get_yields(rows, 'C')

plt.clf()
plt.rcParams['font.family'] = 'Times New Roman'
plt.xlabel('% Carbon Content')
plt.ylabel('% Yield')
plt.scatter(carbon, char, color=(0, 158/235, 115/235), label='Char', alpha=0.5)
plt.savefig('_plots/inp_tar/all_reactors/carbon_char.png')
plt.show()

# %%
# Carbon vs. Gas Yields

carbon, _, _, gas = get_yields(rows, 'C')

plt.clf()
plt.rcParams['font.family'] = 'Times New Roman'
plt.xlabel('% Carbon Content')
plt.ylabel('% Yield')
plt.scatter(carbon, gas, color=(213/235, 94/235, 0), label='Gas', alpha=0.5)
plt.savefig('_plots/inp_tar/all_reactors/carbon_gas.png')
plt.show()

# %%
# Hydrogen vs. Oil Yield

hydrogen, oil, _, _ = get_yields(rows, 'H')

plt.clf()
plt.rcParams['font.family'] = 'Times New Roman'
plt.xlabel('% Hydrogen Content')
plt.ylabel('% Yield')
plt.scatter(hydrogen, oil, color=(0, 114/235, 178/235), label='Oil', alpha=0.5)
plt.savefig('_plots/inp_tar/all_reactors/hydrogen_oil.png')
plt.show()

# %%
# Hydrogen vs. Char Yield

hydrogen, _, char, _ = get_yields(rows, 'H')

plt.clf()
plt.rcParams['font.family'] = 'Times New Roman'
plt.xlabel('% Hydrogen Content')
plt.ylabel('% Yield')
plt.scatter(hydrogen, char, color=(0, 158/235, 115/235), label='Char', alpha=0.5)
plt.savefig('_plots/inp_tar/all_reactors/hydrogen_char.png')
plt.show()

# %%
# Hydrogen vs. Gas Yield

hydrogen, _, _, gas = get_yields(rows, 'H')

plt.clf()
plt.rcParams['font.family'] = 'Times New Roman'
plt.xlabel('% Hydrogen Content')
plt.ylabel('% Yield')
plt.scatter(hydrogen, gas, color=(213/235, 94/235, 0), label='Gas', alpha=0.5)
plt.savefig('_plots/inp_tar/all_reactors/hydrogen_gas.png')
plt.show()

# %%
# Oxygen vs. Oil Yield

oxygen, oil, _, _ = get_yields(rows, 'O')

plt.clf()
plt.rcParams['font.family'] = 'Times New Roman'
plt.xlabel('% Oxygen Content')
plt.ylabel('% Yield')
plt.scatter(oxygen, oil, color=(0, 114/235, 178/235), label='Oil', alpha=0.5)
plt.savefig('_plots/inp_tar/all_reactors/oxygen_oil.png')
plt.show()

# %%
# Oxygen vs. Char Yield

oxygen, _, char, _ = get_yields(rows, 'O')

plt.clf()
plt.rcParams['font.family'] = 'Times New Roman'
plt.xlabel('% Oxygen Content')
plt.ylabel('% Yield')
plt.scatter(oxygen, char, color=(0, 158/235, 115/235), label='Char', alpha=0.5)
plt.savefig('_plots/inp_tar/all_reactors/oxygen_char.png')
plt.show()

# %%
# Oxygen vs. Gas Yield

oxygen, _, _, gas = get_yields(rows, 'O')

plt.clf()
plt.rcParams['font.family'] = 'Times New Roman'
plt.xlabel('% Oxygen Content')
plt.ylabel('% Yield')
plt.scatter(oxygen, gas, color=(213/235, 94/235, 0), label='Gas', alpha=0.5)
plt.savefig('_plots/inp_tar/all_reactors/oxygen_gas.png')
plt.show()

# %%
# Nitrogen vs. Oil Yields

nitrogen, oil, _, _ = get_yields(rows, 'N')

plt.clf()
plt.rcParams['font.family'] = 'Times New Roman'
plt.xlabel('% Nitrogen Content')
plt.ylabel('% Yield')
plt.scatter(nitrogen, oil, color=(0, 114/235, 178/235), label='Oil', alpha=0.5)
plt.savefig('_plots/inp_tar/all_reactors/nitrogen_oil.png')
plt.show()

# %%
# Nitrogen vs. Char Yields

nitrogen, _, char, _ = get_yields(rows, 'N')

plt.clf()
plt.rcParams['font.family'] = 'Times New Roman'
plt.xlabel('% Nitrogen Content')
plt.ylabel('% Yield')
plt.scatter(nitrogen, char, color=(0, 158/235, 115/235), label='Char', alpha=0.5)
plt.savefig('_plots/inp_tar/all_reactors/nitrogen_char.png')
plt.show()

# %%
# Nitrogen vs. Gas Yield

nitrogen, _, _, gas = get_yields(rows, 'N')

plt.clf()
plt.rcParams['font.family'] = 'Times New Roman'
plt.xlabel('% Nitrogen Content')
plt.ylabel('% Yield')
plt.scatter(nitrogen, gas, color=(213/235, 94/235, 0), label='Gas', alpha=0.5)
plt.savefig('_plots/inp_tar/all_reactors/nitrogen_gas.png')
plt.show()
