# %%
from csv import DictReader

with open('../_data/tubular_reactor.csv', 'r') as csv_file:
    reader = DictReader(csv_file)
    rows1 = [r for r in reader]
csv_file.close()

with open('../_data/batch_reactor.csv', 'r') as csv_file:
    reader = DictReader(csv_file)
    rows2 = [r for r in reader]
csv_file.close()

with open('../_data/fluidized_bed.csv', 'r') as csv_file:
    reader = DictReader(csv_file)
    rows3 = [r for r in reader]
csv_file.close()

rows = rows1[:]
rows.extend(rows2)
rows.extend(rows3)

print(len(rows))
# Out:
# 157

# %%
from typing import List, Tuple

def get_yields(rows: List[dict], inp: str, inp_limit: int = None) -> Tuple[List[float]]:
    """ Only retrieves samples with all data (input var, % yields) available """

    input, oil, char, gas = [], [], [], []
    for row in rows:
        try:
            _i = float(row[inp])
            if inp_limit:
                if _i > inp_limit: continue
            _o = float(row['Oil'])
            _c = float(row['Char'])
            _g = float(row['Gas'])
            input.append(_i)
            oil.append(_o)
            char.append(_c)
            gas.append(_g)
        except:
            continue
    return (input, oil, char, gas)

# %%
# Reaction temperature vs. yields
from matplotlib import pyplot as plt

t_reaction, oil, char, gas = get_yields(rows, 'Temperature (C)')

plt.clf()
plt.rcParams['font.family'] = 'Times New Roman'
plt.xlabel('Reaction temperature ($^\circ C$)')
plt.ylabel('Oil mass fraction (%)')
plt.ylim((0.0, 100.0))
plt.scatter(t_reaction, oil, color=(0, 114/235, 178/235), label='Oil', alpha=0.5)
plt.savefig('_plots/all_reactors/reaction_temp_oil.png', dpi=200)
plt.show()

plt.clf()
plt.rcParams['font.family'] = 'Times New Roman'
plt.xlabel('Reaction temperature ($^\circ C$)')
plt.ylabel('Char mass fraction (%)')
plt.ylim((0.0, 100.0))
plt.scatter(t_reaction, char, color=(0, 158/235, 115/235), label='Char', alpha=0.5)
plt.savefig('_plots/all_reactors/reaction_temp_char.png', dpi=200)
plt.show()

plt.clf()
plt.rcParams['font.family'] = 'Times New Roman'
plt.xlabel('Reaction temperature ($^\circ C$)')
plt.ylabel('Gas mass fraction (%)')
plt.ylim((0.0, 100.0))
plt.scatter(t_reaction, gas, color=(213/235, 94/235, 0), label='Gas', alpha=0.5)
plt.savefig('_plots/all_reactors/reaction_temp_gas.png', dpi=200)
plt.show()

# %%
# Reaction time vs. yields (0-30 seconds)
t_reaction, oil, char, gas = get_yields(rows, 'Reaction Time (s)', 30.0)

plt.clf()
plt.rcParams['font.family'] = 'Times New Roman'
plt.xlabel('Reaction time (s)')
plt.ylabel('Oil mass fraction (%)')
plt.ylim((0.0, 100.0))
plt.scatter(t_reaction, oil, color=(0, 114/235, 178/235), label='Oil', alpha=0.5)
plt.savefig('_plots/all_reactors/reaction_time_oil_30.png', dpi=200)
plt.show()

plt.clf()
plt.rcParams['font.family'] = 'Times New Roman'
plt.xlabel('Reaction time (s)')
plt.ylabel('Char mass fraction (%)')
plt.ylim((0.0, 100.0))
plt.scatter(t_reaction, char, color=(0, 158/235, 115/235), label='Char', alpha=0.5)
plt.savefig('_plots/all_reactors/reaction_time_char_30.png', dpi=200)
plt.show()

plt.clf()
plt.rcParams['font.family'] = 'Times New Roman'
plt.xlabel('Reaction time (s)')
plt.ylabel('Gas mass fraction (%)')
plt.ylim((0.0, 100.0))
plt.scatter(t_reaction, gas, color=(213/235, 94/235, 0), label='Gas', alpha=0.5)
plt.savefig('_plots/all_reactors/reaction_time_gas_30.png', dpi=200)
plt.show()

# %%
# Reaction time vs. yields (0-10 seconds)
t_reaction, oil, char, gas = get_yields(rows, 'Reaction Time (s)', 10.0)

plt.clf()
plt.rcParams['font.family'] = 'Times New Roman'
plt.xlabel('Reaction time (s)')
plt.ylabel('Oil mass fraction (%)')
plt.ylim((0.0, 100.0))
plt.scatter(t_reaction, oil, color=(0, 114/235, 178/235), label='Oil', alpha=0.5)
plt.savefig('_plots/all_reactors/reaction_time_oil_10.png', dpi=200)
plt.show()

plt.clf()
plt.rcParams['font.family'] = 'Times New Roman'
plt.xlabel('Reaction time (s)')
plt.ylabel('Char mass fraction (%)')
plt.ylim((0.0, 100.0))
plt.scatter(t_reaction, char, color=(0, 158/235, 115/235), label='Char', alpha=0.5)
plt.savefig('_plots/all_reactors/reaction_time_char_10.png', dpi=200)
plt.show()

plt.clf()
plt.rcParams['font.family'] = 'Times New Roman'
plt.xlabel('Reaction time (s)')
plt.ylabel('Gas mass fraction (%)')
plt.ylim((0.0, 100.0))
plt.scatter(t_reaction, gas, color=(213/235, 94/235, 0), label='Gas', alpha=0.5)
plt.savefig('_plots/all_reactors/reaction_time_gas_10.png', dpi=200)
plt.show()

# %%
# Reaction time vs. yields (no x limit)
t_reaction, oil, char, gas = get_yields(rows, 'Reaction Time (s)')

plt.clf()
plt.rcParams['font.family'] = 'Times New Roman'
plt.xlabel('Reaction time (s)')
plt.ylabel('Oil mass fraction (%)')
plt.ylim((0.0, 100.0))
plt.scatter(t_reaction, oil, color=(0, 114/235, 178/235), label='Oil', alpha=0.5)
plt.savefig('_plots/all_reactors/reaction_time_oil.png', dpi=200)
plt.show()

plt.clf()
plt.rcParams['font.family'] = 'Times New Roman'
plt.xlabel('Reaction time (s)')
plt.ylabel('Char mass fraction (%)')
plt.ylim((0.0, 100.0))
plt.scatter(t_reaction, char, color=(0, 158/235, 115/235), label='Char', alpha=0.5)
plt.savefig('_plots/all_reactors/reaction_time_char.png', dpi=200)
plt.show()

plt.clf()
plt.rcParams['font.family'] = 'Times New Roman'
plt.xlabel('Reaction time (s)')
plt.ylabel('Gas mass fraction (%)')
plt.ylim((0.0, 100.0))
plt.scatter(t_reaction, gas, color=(213/235, 94/235, 0), label='Gas', alpha=0.5)
plt.savefig('_plots/all_reactors/reaction_time_gas.png', dpi=200)
plt.show()

# %%
# Reaction time vs. yields (500 seconds)
t_reaction, oil, char, gas = get_yields(rows, 'Reaction Time (s)', 500.0)

plt.clf()
plt.rcParams['font.family'] = 'Times New Roman'
plt.xlabel('Reaction time (s)')
plt.ylabel('Oil mass fraction (%)')
plt.ylim((0.0, 100.0))
plt.scatter(t_reaction, oil, color=(0, 114/235, 178/235), label='Oil', alpha=0.5)
plt.savefig('_plots/all_reactors/reaction_time_oil_500.png', dpi=200)
plt.show()

plt.clf()
plt.rcParams['font.family'] = 'Times New Roman'
plt.xlabel('Reaction time (s)')
plt.ylabel('Char mass fraction (%)')
plt.ylim((0.0, 100.0))
plt.scatter(t_reaction, char, color=(0, 158/235, 115/235), label='Char', alpha=0.5)
plt.savefig('_plots/all_reactors/reaction_time_char_500.png', dpi=200)
plt.show()

plt.clf()
plt.rcParams['font.family'] = 'Times New Roman'
plt.xlabel('Reaction time (s)')
plt.ylabel('Gas mass fraction (%)')
plt.ylim((0.0, 100.0))
plt.scatter(t_reaction, gas, color=(213/235, 94/235, 0), label='Gas', alpha=0.5)
plt.savefig('_plots/all_reactors/reaction_time_gas_500.png', dpi=200)
plt.show()
